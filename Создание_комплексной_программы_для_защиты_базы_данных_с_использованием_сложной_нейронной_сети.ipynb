# %% [markdown]
# Создание комплексной программы для защиты базы данных с использованием сложной нейронной сети требует значительных усилий. Я предоставлю вам более подробный пример, который включает следующие шаги:
#
# 1. Загрузка данных и предварительная обработка
# 2. Создание сложной архитектуры нейронной сети
# 3. Обучение и оценка модели
# 4. Построение графика надежности
# 5. Визуализация компьютерной сети
#
# Обратите внимание, что этот пример все еще упрощен для пояснения и иллюстрации. В реальном сценарии вам нужно будет учитывать гораздо больше аспектов, таких как более сложные архитектуры нейронных сетей, улучшенная предварительная обработка данных, обработка различных типов атак и многое другое.

# %%
import numpy as np
import tensorflow as tf
import networkx as nx
import matplotlib.pyplot as plt

# Определите количество образцов и признаков
num_samples = 2000  # Отрегулируйте количество образцов по мере необходимости
num_features = 10   # Отрегулируйте количество функций по мере необходимости

# Шаг 1: Загрузите и предварительно обработайте данные (аналогично предыдущему примеру)
normal_data = np.random.randn(num_samples, num_features)
attack_data = np.random.randn(num_samples, num_features) + 3.0
data = np.vstack([normal_data, attack_data])
labels = np.hstack([np.zeros(num_samples), np.ones(num_samples)])
shuffle_indices = np.random.permutation(len(data))
data = data[shuffle_indices]
labels = labels[shuffle_indices]
train_ratio = 0.8
train_size = int(train_ratio * len(data))
train_data, test_data = data[:train_size], data[train_size:]
train_labels, test_labels = labels[:train_size], labels[train_size:]

# Шаг 2. Создайте более сложную архитектуру нейронной сети.
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(num_features,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Скомпилируйте модель
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Шаг 3: Обучите модель
model.fit(train_data, train_labels, epochs=100, batch_size=32, validation_split=0.1)

# Шаг 4. Делайте прогнозы на основе тестовых данных
predictions = model.predict(test_data)

# Шаг 5. Постройте график надежности
G = nx.Graph()

for i in range(len(test_data)):
    G.add_node(i, label=test_labels[i], prediction=predictions[i][0])

for i in range(len(test_data)):
    for j in range(i + 1, len(test_data)):
        if test_labels[i] == test_labels[j]:
            G.add_edge(i, j, weight=abs(predictions[i][0] - predictions[j][0]))

# Шаг 5: Создайте и визуализируйте компьютерную сеть
computer_network = nx.Graph()
computer_positions = {
    0: (0, 0),
    1: (1, 0),
    2: (0, 1),
    3: (1, 1)
}

computer_labels = {
    0: "Computer 0",
    1: "Computer 1",
    2: "Computer 2",
    3: "Computer 3"
}

computer_network.add_nodes_from(computer_positions.keys())
computer_network.add_edges_from([(0, 1), (1, 2), (2, 3), (3, 0)])

plt.figure(figsize=(8, 6))

# Нарисуйте компьютерную сеть
nx.draw(
    computer_network,
    pos=computer_positions,
    with_labels=True,
    labels=computer_labels,
    node_size=1000,
    node_color='lightblue',
    font_size=10,
    font_color='black',
    font_weight='bold',
    edge_color='gray'
)

plt.title("Компьютерная сеть")

# Отображение графика надежности отдельно или на одном графике
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G)
nx.draw(
    G,
    pos,
    with_labels=True,
    font_weight='bold',
    node_color=[predictions[i][0] for i in G.nodes()],
    cmap=plt.get_cmap('coolwarm'),
    node_size=2000
)

plt.title("График надежности")

plt.show()
# Out:
# Epoch 1/100
# 90/90 [==============================] - 10s 11ms/step - loss: 0.2783 - accuracy: 0.9028 - val_loss: 0.0662 - val_accuracy: 0.9937
# Epoch 2/100
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0436 - accuracy: 0.9951 - val_loss: 0.0177 - val_accuracy: 0.9937
# Epoch 3/100
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9976 - val_loss: 0.0086 - val_accuracy: 0.9969
# Epoch 4/100
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 0.9976 - val_loss: 0.0055 - val_accuracy: 0.9969
# Epoch 5/100
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.9986 - val_loss: 0.0076 - val_accuracy: 0.9969
# Epoch 6/100
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.0047 - val_accuracy: 0.9969
# Epoch 7/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0030 - val_accuracy: 0.9969
# Epoch 8/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.0034 - val_accuracy: 0.9969
# Epoch 9/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0036 - val_accuracy: 0.9969
# Epoch 10/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 0.9969
# Epoch 11/100
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0045 - val_accuracy: 0.9969
# Epoch 12/100
# 90/90 [==============================] - 0s 3ms/step - loss: 8.8792e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 0.9969
# Epoch 13/100
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 0.9969
# Epoch 14/100
# 90/90 [==============================] - 0s 3ms/step - loss: 8.6196e-04 - accuracy: 0.9997 - val_loss: 0.0023 - val_accuracy: 0.9969
# Epoch 15/100
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0042 - val_accuracy: 0.9969
# Epoch 16/100
# 90/90 [==============================] - 0s 3ms/step - loss: 5.7091e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 0.9969
# Epoch 17/100
# 90/90 [==============================] - 0s 3ms/step - loss: 7.7239e-04 - accuracy: 0.9997 - val_loss: 0.0031 - val_accuracy: 0.9969
# Epoch 18/100
# 90/90 [==============================] - 0s 3ms/step - loss: 4.9369e-04 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 0.9969
# Epoch 19/100
# 90/90 [==============================] - 0s 4ms/step - loss: 6.9992e-04 - accuracy: 0.9997 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 20/100
# 90/90 [==============================] - 0s 4ms/step - loss: 4.8849e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 0.9969
# Epoch 21/100
# 90/90 [==============================] - 0s 4ms/step - loss: 8.8901e-04 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 22/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.9688e-04 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 0.9969
# Epoch 23/100
# 90/90 [==============================] - 0s 4ms/step - loss: 5.1928e-04 - accuracy: 0.9997 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 24/100
# 90/90 [==============================] - 0s 3ms/step - loss: 1.5077e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 25/100
# 90/90 [==============================] - 0s 3ms/step - loss: 1.5874e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 26/100
# 90/90 [==============================] - 0s 4ms/step - loss: 2.1298e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 27/100
# 90/90 [==============================] - 0s 3ms/step - loss: 2.2862e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 28/100
# 90/90 [==============================] - 0s 3ms/step - loss: 5.0779e-04 - accuracy: 0.9997 - val_loss: 0.0042 - val_accuracy: 0.9969
# Epoch 29/100
# 90/90 [==============================] - 0s 4ms/step - loss: 2.0490e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 0.9969
# Epoch 30/100
# 90/90 [==============================] - 0s 3ms/step - loss: 2.9628e-04 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 0.9969
# Epoch 31/100
# 90/90 [==============================] - 0s 3ms/step - loss: 4.0416e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 32/100
# 90/90 [==============================] - 0s 3ms/step - loss: 8.6874e-05 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 33/100
# 90/90 [==============================] - 0s 3ms/step - loss: 6.9434e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 34/100
# 90/90 [==============================] - 0s 4ms/step - loss: 7.2247e-05 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 35/100
# 90/90 [==============================] - 0s 4ms/step - loss: 7.5500e-04 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 0.9969
# Epoch 36/100
# 90/90 [==============================] - 0s 4ms/step - loss: 9.5526e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 37/100
# 90/90 [==============================] - 0s 3ms/step - loss: 7.0247e-04 - accuracy: 0.9997 - val_loss: 0.0074 - val_accuracy: 0.9969
# Epoch 38/100
# 90/90 [==============================] - 0s 3ms/step - loss: 1.0704e-04 - accuracy: 1.0000 - val_loss: 6.5195e-04 - val_accuracy: 1.0000
# Epoch 39/100
# 90/90 [==============================] - 0s 4ms/step - loss: 5.7251e-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 40/100
# 90/90 [==============================] - 0s 3ms/step - loss: 4.2532e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 41/100
# 90/90 [==============================] - 0s 3ms/step - loss: 1.1168e-04 - accuracy: 1.0000 - val_loss: 6.3217e-04 - val_accuracy: 1.0000
# Epoch 42/100
# 90/90 [==============================] - 0s 5ms/step - loss: 9.1413e-05 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 0.9969
# Epoch 43/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.2482e-04 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 44/100
# 90/90 [==============================] - 0s 5ms/step - loss: 6.1147e-05 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 45/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.1470e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 46/100
# 90/90 [==============================] - 0s 5ms/step - loss: 4.1246e-05 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 47/100
# 90/90 [==============================] - 0s 5ms/step - loss: 7.2547e-05 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 48/100
# 90/90 [==============================] - 0s 4ms/step - loss: 4.3343e-05 - accuracy: 1.0000 - val_loss: 9.0621e-04 - val_accuracy: 1.0000
# Epoch 49/100
# 90/90 [==============================] - 0s 4ms/step - loss: 4.0431e-05 - accuracy: 1.0000 - val_loss: 6.4605e-04 - val_accuracy: 1.0000
# Epoch 50/100
# 90/90 [==============================] - 0s 3ms/step - loss: 6.1080e-05 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 51/100
# 90/90 [==============================] - 0s 4ms/step - loss: 3.2030e-05 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 52/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.1799e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 53/100
# 90/90 [==============================] - 0s 4ms/step - loss: 3.5466e-05 - accuracy: 1.0000 - val_loss: 7.9372e-04 - val_accuracy: 1.0000
# Epoch 54/100
# 90/90 [==============================] - 0s 3ms/step - loss: 2.1195e-05 - accuracy: 1.0000 - val_loss: 9.8340e-04 - val_accuracy: 1.0000
# Epoch 55/100
# 90/90 [==============================] - 0s 4ms/step - loss: 7.6033e-05 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 0.9969
# Epoch 56/100
# 90/90 [==============================] - 0s 4ms/step - loss: 2.0007e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 0.9969
# Epoch 57/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.6159e-05 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 0.9969
# Epoch 58/100
# 90/90 [==============================] - 0s 4ms/step - loss: 2.4731e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 59/100
# 90/90 [==============================] - 0s 4ms/step - loss: 7.4846e-05 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 60/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.1669e-05 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 61/100
# 90/90 [==============================] - 0s 4ms/step - loss: 9.7113e-04 - accuracy: 0.9997 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 62/100
# 90/90 [==============================] - 0s 4ms/step - loss: 9.8019e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 63/100
# 90/90 [==============================] - 0s 4ms/step - loss: 3.9671e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 64/100
# 90/90 [==============================] - 0s 4ms/step - loss: 8.2038e-06 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 65/100
# 90/90 [==============================] - 0s 3ms/step - loss: 1.5126e-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 66/100
# 90/90 [==============================] - 0s 4ms/step - loss: 5.5330e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 0.9969
# Epoch 67/100
# 90/90 [==============================] - 0s 4ms/step - loss: 6.9943e-06 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 0.9969
# Epoch 68/100
# 90/90 [==============================] - 0s 3ms/step - loss: 1.2385e-05 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 0.9969
# Epoch 69/100
# 90/90 [==============================] - 0s 4ms/step - loss: 2.9943e-05 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 70/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.3870e-04 - accuracy: 1.0000 - val_loss: 2.2369e-04 - val_accuracy: 1.0000
# Epoch 71/100
# 90/90 [==============================] - 0s 4ms/step - loss: 5.0479e-04 - accuracy: 0.9997 - val_loss: 0.0057 - val_accuracy: 0.9969
# Epoch 72/100
# 90/90 [==============================] - 0s 4ms/step - loss: 2.5630e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 73/100
# 90/90 [==============================] - 0s 4ms/step - loss: 7.5986e-05 - accuracy: 1.0000 - val_loss: 9.8107e-04 - val_accuracy: 1.0000
# Epoch 74/100
# 90/90 [==============================] - 0s 4ms/step - loss: 2.5343e-05 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 75/100
# 90/90 [==============================] - 0s 4ms/step - loss: 8.8524e-06 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 76/100
# 90/90 [==============================] - 0s 4ms/step - loss: 3.0614e-06 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 0.9969
# Epoch 77/100
# 90/90 [==============================] - 0s 5ms/step - loss: 5.1503e-06 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 78/100
# 90/90 [==============================] - 0s 5ms/step - loss: 7.2925e-06 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9969
# Epoch 79/100
# 90/90 [==============================] - 0s 6ms/step - loss: 1.2330e-05 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 0.9969
# Epoch 80/100
# 90/90 [==============================] - 0s 5ms/step - loss: 6.4632e-06 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 0.9969
# Epoch 81/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.6534e-05 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 0.9969
# Epoch 82/100
# 90/90 [==============================] - 0s 5ms/step - loss: 1.7422e-05 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 0.9969
# Epoch 83/100
# 90/90 [==============================] - 0s 4ms/step - loss: 7.3245e-06 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 0.9969
# Epoch 84/100
# 90/90 [==============================] - 0s 3ms/step - loss: 1.7352e-05 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 85/100
# 90/90 [==============================] - 0s 3ms/step - loss: 9.8685e-06 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 0.9969
# Epoch 86/100
# 90/90 [==============================] - 0s 3ms/step - loss: 8.8499e-06 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 0.9969
# Epoch 87/100
# 90/90 [==============================] - 0s 4ms/step - loss: 4.8332e-06 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 0.9969
# Epoch 88/100
# 90/90 [==============================] - 0s 3ms/step - loss: 2.9693e-05 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9969
# Epoch 89/100
# 90/90 [==============================] - 0s 3ms/step - loss: 1.4738e-05 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9969
# Epoch 90/100
# 90/90 [==============================] - 0s 4ms/step - loss: 3.5603e-05 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9969
# Epoch 91/100
# 90/90 [==============================] - 0s 4ms/step - loss: 2.0547e-04 - accuracy: 1.0000 - val_loss: 2.0527e-04 - val_accuracy: 1.0000
# Epoch 92/100
# 90/90 [==============================] - 0s 4ms/step - loss: 3.8672e-05 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 93/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.8403e-05 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 94/100
# 90/90 [==============================] - 0s 4ms/step - loss: 4.2097e-06 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 95/100
# 90/90 [==============================] - 0s 4ms/step - loss: 4.1349e-06 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 96/100
# 90/90 [==============================] - 0s 3ms/step - loss: 3.3071e-06 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 97/100
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0128 - val_accuracy: 0.9969
# Epoch 98/100
# 90/90 [==============================] - 0s 3ms/step - loss: 1.3425e-04 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9969
# Epoch 99/100
# 90/90 [==============================] - 0s 4ms/step - loss: 1.0181e-05 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 100/100
# 90/90 [==============================] - 0s 3ms/step - loss: 1.6373e-05 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9969
# 25/25 [==============================] - 1s 3ms/step

# %% [markdown]
# Обратите внимание, что приведенный выше код все еще довольно упрощен и служит иллюстрацией концепции. Создание действительно эффективного решения для обеспечения безопасности потребует более полных данных, более совершенных архитектур нейронных сетей и более совершенных методов борьбы с угрозами безопасности.
